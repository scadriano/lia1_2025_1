# %% [markdown]
# <hr style="height:10px">
#
# <div class='container2'>
# 		<div>
# 			<img src='images\dataset-cover.png' ALIGN='left' style='width:10em'>
# 		</div>
# 	<div style='padding: 0 7em 2em 12em;'>
# 	<h1>Laboratório de Inovação e Automação 1 (LIA 1)</h1>
# 	<div style="font-size:12pt;float:left;"> 2025/1 | 46M34 | Sala 200 CAE</div><br><br>
#     <div style="font-size:12pt;float:left;"><b>Projetos de Inteligência Artificial - Análise Exploratória de Dados </b></div>
# 	</div>
# </div>
#
#
#  <hr style="height:5px">
#
#
# <h2>Aula 7 - Introdução à Ciência de Dados - <a href="https://www.kaggle.com/datasets/raomuhammadsaeedali/brazil-dengue-dataset-2000-2019?resource=download">Brazil Dengue Dataset 2000-2019</a> </h2>
#
# Notebook desenvolvido por: <a href="">Guilherme Moreira Cruz Cardoso</a>
#
#  <hr style="height:2px">

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

print('Bibliotecas carregadas com sucesso!')
# Out:
# Bibliotecas carregadas com sucesso!

# %%
# Confirmar a versão da Linguagem Python instalada
from platform import python_version
print(f'A versão da linguagem Python usada neste projeto é a {python_version()}!')
# Out:
# A versão da linguagem Python usada neste projeto é a 3.12.7!

# %% [markdown]
# ---
# ## 1. Bibliotecas Necessárias para o Notebook (Aula)
#
# Para este notebook, deve ser utilizada a mesma versão apresentada pelo professor da disciplina.
#
# * [`matplotlib`](https://matplotlib.org/) (versão 3.1.3 ou superior): construção e exibição de gráficos variados.
# * [`seaborn`](https://seaborn.pydata.org/) (versão 0.10.0 ou superior): construção e exibição de gráficos variados.
# * [`numpy`](https://numpy.org) (versão 1.16.2 ou superior): manipulação de dados em formato de vetores e matrizes.
# * [`pandas`](https://pandas.pydata.org/pandas-docs/stable/index.html) (versão 0.24.1 ou superior): manipulação de dados em formato de tabelas.
#
# Será utilizado o conjunto de dados que se encontra no diretório `datasets`, em formato de arquivo `.csv e/ou .txt`.

# %% [markdown]
# ---
# ## 2. Carregar e Exibir os Dados da Fonte
#
# Primeiro, vamos importar todas as bibliotecas que serão utilizadas no projeto.

# %%
# -*- coding: utf-8 -*-

# importar a biblioteca usada para trabalhar com vetores e matrizes
import numpy as np

# importar a biblioteca usada para trabalhar com dataframes (dados em formato de tabela) e análise de dados
import pandas as pd 

# importar as bibliotecas usadas para geração de gráficos
import seaborn as sns
import matplotlib.pyplot as plt

print('Bibliotecas carregadas com sucesso!')
# Out:
# Bibliotecas carregadas com sucesso!

# %% [markdown]
# ### Apresentação da base de dados
#
# A base de dados Brazil Dengue Dataset 2000-2019 - O conjunto de dados sobre a dengue no Brasil oferece insights sobre geografia, meio ambiente e doenças. - será usada para apresentação dos conceitos a serem estudados.

# %% [markdown]
# Primeiro: vamos importar os dados para o dataframe.

# %%
# importar o arquivo e guardar em um dataframe do Pandas
df_dataset = pd.read_csv ( 'datasets/data_2000_2019.csv', sep=',', index_col=None)

print('Dados importados com sucesso!')
# Out:
# Dados importados com sucesso!

# %% [markdown]
# Segundo: vamos dar uma olhada rápida na base de dados.

# %%
# exibir uma amostra do dataframe
#display(df_dataset.head())
display(df_dataset)
# Out:
#         micro_code        micro_name   micro_name_ibge  meso_code  \
# 0            11001       Porto Velho       PORTO VELHO       1101
# 1            11002  Guajar<e1>-Mirim     GUAJARÁ-MIRIM       1101
# 2            11003         Ariquemes         ARIQUEMES       1102
# 3            11004      Ji-Paran<e1>         JI-PARANÁ       1102
# 4            11005  Alvorada D'Oeste  ALVORADA D'OESTE       1102
# ...            ...               ...               ...        ...
# 133915       52015        Meia Ponte        MEIA PONTE       5205
# 133916       52016      Pires do Rio      PIRES DO RIO       5205
# 133917       52017        Catal<e3>o           CATALÃO       5205
# 133918       52018   Quirin<f3>polis      QUIRINÓPOLIS       5205
# 133919       53001       Bras<ed>lia          BRASÍLIA       5301
#
#                 meso_name  state_code        state_name  region_code  \
# 0         Madeira-Guaporé          11          Rondônia            1
# 1         Madeira-Guaporé          11          Rondônia            1
# 2       Leste Rondoniense          11          Rondônia            1
# 3       Leste Rondoniense          11          Rondônia            1
# 4       Leste Rondoniense          11          Rondônia            1
# ...                   ...         ...               ...          ...
# 133915         Sul Goiano          52             Goiás            5
# 133916         Sul Goiano          52             Goiás            5
# 133917         Sul Goiano          52             Goiás            5
# 133918         Sul Goiano          52             Goiás            5
# 133919   Distrito Federal          53  Distrito Federal            5
#
#         region_name  biome_code  ... time  dengue_cases population  \
# 0             North           5  ...    1           NaN        NaN
# 1             North           5  ...    1           NaN        NaN
# 2             North           5  ...    1           NaN        NaN
# 3             North           5  ...    1           NaN        NaN
# 4             North           5  ...    1           NaN        NaN
# ...             ...         ...  ...  ...           ...        ...
# 133915  Centre-West           2  ...  240         111.0   409691.0
# 133916  Centre-West           2  ...  240          42.0   100780.0
# 133917  Centre-West           2  ...  240          57.0   176527.0
# 133918  Centre-West           2  ...  240          41.0   128463.0
# 133919  Centre-West           2  ...  240         576.0  3015268.0
#
#        pop_density       tmax       tmin      pdsi  urban  water_network  \
# 0              NaN  30.544556  21.751202 -1.790602  85.20          33.57
# 1              NaN  31.005884  21.641306  0.629408  72.31          27.43
# 2              NaN  30.444357  21.492065 -3.455422  66.91          27.76
# 3              NaN  30.458706  21.111828 -1.586286  68.68          32.23
# 4              NaN  30.616793  21.053421 -0.043228  42.82          21.40
# ...            ...        ...        ...       ...    ...            ...
# 133915   19.397264  31.148733  21.699646 -2.526940  89.69          79.10
# 133916   10.579541  29.929796  20.871635 -1.855514  72.80          71.34
# 133917   11.591627  30.154041  20.992001 -2.663716  89.47          88.74
# 133918    7.991280  32.152596  22.195051 -3.365225  85.36          77.39
# 133919  521.289159  28.822147  19.971571 -1.842697  96.77          94.82
#
#         water_shortage
# 0               0.2245
# 1               0.0873
# 2               0.1871
# 3               0.2381
# 4               0.2837
# ...                ...
# 133915          0.4656
# 133916          0.2444
# 133917          0.6508
# 133918          0.4802
# 133919          0.8730
#
# [133920 rows x 26 columns]

# %% [markdown]
# ---
# ## 3. Pré-processamento
#
# Minimizar ou eliminar problemas existentes em um conjunto de dados, bem como torná-los mais adequados para sua utilização por um determinado algoritmo de aprendizagem de máquina.
#
# ## 3.1 Eliminação de atributos irrelevantes
#
# O objetivo do projeto é identificar as regiões, estados e biomas com mais ocorrências de casos de dengue no Brasil, e identificar suas características.
#
# *Em cenários reais, muitas vezes é necessário consultar especialistas para ajudar a identificar quais atributos são irrelevantes.*

# %%
# remover as colunas id_planta e cidade_origem
df_dataset = df_dataset.drop(columns=['micro_code','micro_name','micro_name_ibge','meso_code','meso_name','ecozone_code','ecozone_name','time',
                                      'dengue_cases','population','pop_density','pdsi','urban','water_network','water_shortage','tmax','tmin'])

# imprimir o dataframe
display(df_dataset.tail(n=10))
# Out:
#         state_code        state_name  region_code  region_name  biome_code  \
# 133910          52             Goiás            5  Centre-West           2
# 133911          52             Goiás            5  Centre-West           2
# 133912          52             Goiás            5  Centre-West           2
# 133913          52             Goiás            5  Centre-West           2
# 133914          52             Goiás            5  Centre-West           2
# 133915          52             Goiás            5  Centre-West           2
# 133916          52             Goiás            5  Centre-West           2
# 133917          52             Goiás            5  Centre-West           2
# 133918          52             Goiás            5  Centre-West           2
# 133919          53  Distrito Federal            5  Centre-West           2
#
#        biome_name main_climate  month  year
# 133910    Cerrado           AW     12  2019
# 133911    Cerrado           AW     12  2019
# 133912    Cerrado           AW     12  2019
# 133913    Cerrado           AW     12  2019
# 133914    Cerrado           AW     12  2019
# 133915    Cerrado           AW     12  2019
# 133916    Cerrado           AW     12  2019
# 133917    Cerrado           AW     12  2019
# 133918    Cerrado           AW     12  2019
# 133919    Cerrado           AW     12  2019

# %% [markdown]
# ---
# ## 3.2 Tratamento de atributos com valores ausentes
#
# Verificar se existem atributos com valores ausentes (NaN) na base de dados.

# %%
# índices das linhas que contém valores NaN
idxRowNan = pd.isnull(df_dataset).any(axis=1).to_numpy().nonzero()

# imprime apenas as linhas com valores ausentes
display(df_dataset.iloc[idxRowNan])
# Out:
# Empty DataFrame
# Columns: [state_code, state_name, region_code, region_name, biome_code, biome_name, main_climate, month, year]
# Index: []

# %% [markdown]
# Nenhum atributo com valor ausente.

# %% [markdown]
# ---
# ## 3.3 Tratamento de dados inconsistentes ou redundantes
#
# Verificar se existem dados inconsistentes ou redundantes. A forma mais comum de inconsistência é quando há registros representados por atributos com todos os valores iguais, mas com diagnóstico diferentes. A redundância é dada pela repetição de linhas na base de dados.
#
# *Não é útil para esse caso*

# %% [markdown]
# ---
# ## 4. Análise dos Dados
# A análise das características presentes em um conjunto de dados permite a descoberta de padrões e tendências que podem fornecer informações valiosas para compreender o processo que gerou os dados.

# %%
# apresenta as principais estatísticas da base de dados para atributos numéricos
df_detalhes = df_dataset.describe()

display(df_detalhes)
# Out:
#           state_code    region_code     biome_code          month  \
# count  133920.000000  133920.000000  133920.000000  133920.000000
# mean       31.302867       2.788530       3.935484       6.500000
# std        10.385255       1.136753       2.134247       3.452065
# min        11.000000       1.000000       1.000000       1.000000
# 25%        24.000000       2.000000       2.000000       3.750000
# 50%        31.000000       3.000000       5.000000       6.500000
# 75%        41.000000       4.000000       6.000000       9.250000
# max        53.000000       5.000000       6.000000      12.000000
#
#                 year
# count  133920.000000
# mean     2009.500000
# std         5.766303
# min      2000.000000
# 25%      2004.750000
# 50%      2009.500000
# 75%      2014.250000
# max      2019.000000

# %% [markdown]
# ---
# ## 4.1 Detecção de outliers (valor atípico)
# Outro passo importante na análise e tratamento dos dados é a detecção de outliers (dados gerados por leituras incorretas, erros de digitação etc).

# %% [markdown]
# `Gráfico Box Plot`
#
# Uma das maneiras mais simples de verificar se os dados contém outliers.

# %%
# gerar um bloxplot para cada atributo
df_dataset.boxplot(figsize=(15,7))
plt.show()
